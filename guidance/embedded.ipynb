# %%
import fasttext

# %%
model = fasttext.train_unsupervised("./guidance/task.txt", model="skipgram",loss="softmax",lrUpdateRate=0.25, epoch=100)
# Out:
# Read 0M words
# Number of words:  1085
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   41678 lr:  0.000000 avg.loss:  2.886704 ETA:   0h 0m 0s

# %%
print(model.words)
print(model["king"])
# Out:
# ['</s>', 'ការ', 'បាន', 'ជា', 'និង', 'នៅ', 'ថា', 'នេះ', 'ដែល', 'ពី', 'លោក', 'មាន', 'របស់', 'ក្នុង', 'រដ្ឋ', 'ទៅ', 'កម្ពុជា', 'នឹង', 'ដោយ', 'ទាំង', 'ចិន', 'នោះ', 'ប្រទេស', 'មិន', 'អ្នក', 'ទី', 'ឱ្យ', 'ហើយ', 'ជាតិ', 'ភាព', 'ឆ្នាំ', 'ធ្វើ', 'ថ្ងៃ', 'មួយ', 'តែ', 'មក', 'មន្ត្រី', 'ពល', 'លើ', 'ខែ', 'ទៀត', 'គឺ', 'តាម', 'ត្រូវ', 'ខ្លួន', 'ដើម្បី', 'នាក់', 'ឡើង', 'ក្រុម', 'ខេត្ត', 'នាំ', 'នៃ', 'ចំនួន', 'ខាង', 'ជន', 'ក៏', 'កាល', 'ដី', 'ពេល', 'អាមេរិក', 'ដល់', 'គេ', 'រដ្ឋាភិបាល', 'កិច្ច', 'ឬ', 'ឲ្យ', 'ដែន', 'វៀតណាម', 'សហ', 'ទឹក', 'ច្បាប់', 'ខ្មែរ', 'បន្ត', 'កម្ម', 'កង', 'ប្រជា', 'ទេ', 'រក', 'គ្នា', 'អង្គ', 'អោយ', 'យ៉ាង', 'តំបន់', 'ដឹក', 'ពួក', 'កាន់', 'យក', 'សិទ្ធិ', 'ចូល', 'ព្រះ', 'បក្ស', 'កំពុង', 'ចេញ', 'ច្រើន', 'លើក', 'ឃើញ', 'ក្រសួង', 'សមុទ្រ', 'ទ័ព', 'ក្រុង', 'ជាង', 'ចាប់', 'ៗ', 'បញ្ហា', 'ជំងឺ', 'បទ', 'ព្រំ', 'អាច', 'បាល', 'កោះ', 'ចោទ', 'រួម', 'ចុះ', 'ជាមួយ', 'ដោះ', 'ដែរ', 'ទទួល', 'ដូច', 'ឃុំ', 'មេ', 'កក្កដា', 'រឿង', 'ណា', 'មនុស្ស', 'ឯក', 'នគរ', 'វិញ', 'ត្បូង', 'ជើង', 'ទោស', 'តៃវ៉ាន់', 'ដាក់
# ...
